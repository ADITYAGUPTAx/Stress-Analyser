# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Stress_Dataset.csv")
df
# Out:
#      Gender  Age  Have you recently experienced stress in your life?  \
# 0         0   20                                                  3
# 1         0   20                                                  2
# 2         0   20                                                  5
# 3         1   20                                                  3
# 4         0   20                                                  3
# ..      ...  ...                                                ...
# 838       0   21                                                  3
# 839       1   19                                                  3
# 840       1   19                                                  4
# 841       0   20                                                  5
# 842       0   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                    4
# ...

# %%
df.describe()
# Out:
#            Gender         Age  \
# count  843.000000  843.000000
# mean     0.349941   20.071174
# std      0.477234    5.429502
# min      0.000000   14.000000
# 25%      0.000000   19.000000
# 50%      0.000000   19.000000
# 75%      1.000000   20.000000
# max      1.000000  100.000000
#
#        Have you recently experienced stress in your life?  \
# count                                         843.000000
# mean                                            2.997628
# std                                             1.134639
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Have you noticed a rapid heartbeat or palpitations?  \
# count                                         843.000000
# ...

# %%
df.isnull().sum()
# Out:
# Gender                                                                  0
# Age                                                                     0
# Have you recently experienced stress in your life?                      0
# Have you noticed a rapid heartbeat or palpitations?                     0
# Have you been dealing with anxiety or tension recently?                 0
# Do you face any sleep problems or difficulties falling asleep?          0
# Have you been dealing with anxiety or tension recently?.1               0
# Have you been getting headaches more often than usual?                  0
# Do you get irritated easily?                                            0
# Do you have trouble concentrating on your academic tasks?               0
# Have you been feeling sadness or low mood?                              0
# Have you been experiencing any illness or health issues?                0
# Do you often feel lonely or isolated?                                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 26 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Gender                                                                843 non-null    int64
#  1   Age                                                                   843 non-null    int64
#  2   Have you recently experienced stress in your life?                    843 non-null    int64
#  3   Have you noticed a rapid heartbeat or palpitations?                   843 non-null    int64
#  4   Have you been dealing with anxiety or tension recently?               843 non-null    int64
#  5   Do you face any sleep problems or difficulties falling asleep?        843 non-null    int64
# ...

# %%
df.groupby('Which type of stress do you primarily experience?').size()
# Out:
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.     32
# Eustress (Positive Stress) - Stress that motivates and enhances performance.       768
# No Stress - Currently experiencing minimal to no stress.                            43
# dtype: int64

# %%
768/843 # Means even if it predicts eustress all times accuracy will be 0.911
# Out:
# 0.9110320284697508

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
x=df.drop('Which type of stress do you primarily experience?', axis=1)
y=df['Which type of stress do you primarily experience?']

# %%
x1,x2,y1,y2=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X1, Y1 = smote.fit_resample(x1,y1)

# %%
model=LogisticRegression()
model.fit(X1,Y1)
# Out:
# c:\Users\aditya\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x2,y2)
# Out:
# 0.8224852071005917

# %%
from sklearn.metrics import precision_recall_fscore_support
y_pred = model.predict(x2)
precision, recall, f1, _ = precision_recall_fscore_support(y2, y_pred, average='weighted')

# %%
precision, recall, f1
# Out:
# (0.949847588309127, 0.8224852071005917, 0.8690362891546323)

# %%
from sklearn.tree import DecisionTreeClassifier
model2= DecisionTreeClassifier()

# %%
model2.fit(X1, Y1)
# Out:
# DecisionTreeClassifier()

# %%
model2.score(x2, y2)
# Out:
# 0.9112426035502958

# %%
y_pred=model2.predict(x2)

# %%
precision, recall, f1, _ = precision_recall_fscore_support(y2, y_pred, average='weighted')

precision, recall, f1
# Out:
# (0.9033716646198504, 0.9112426035502958, 0.9060170598632136)

# %%
print(classification_report(y2, y_pred))
# Out:
#                                                                                  precision    recall  f1-score   support
#
# Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.       0.33      0.33      0.33         6
#    Eustress (Positive Stress) - Stress that motivates and enhances performance.       0.94      0.96      0.95       156
#                        No Stress - Currently experiencing minimal to no stress.       0.50      0.29      0.36         7
#
#                                                                        accuracy                           0.91       169
#                                                                       macro avg       0.59      0.53      0.55       169
#                                                                    weighted avg       0.90      0.91      0.91       169

# %%
from sklearn.naive_bayes import CategoricalNB
model3= CategoricalNB()
model3.fit(X1, Y1)
# Out:
# CategoricalNB()

# %%
df['Which type of stress do you primarily experience?'].value_counts(normalize=True)
# Out:
# Which type of stress do you primarily experience?
# Eustress (Positive Stress) - Stress that motivates and enhances performance.       0.911032
# No Stress - Currently experiencing minimal to no stress.                           0.051008
# Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.    0.037960
# Name: proportion, dtype: float64

# %%
model3.score(x2, y2)
# Out:
# 0.9408284023668639

# %%
y_pred=model3.predict(x2)

# %%
precision, recall, f1, _ = precision_recall_fscore_support(y2, y_pred, average='weighted')

precision, recall, f1
# Out:
# (0.9626643988213593, 0.9408284023668639, 0.9456535367466541)

# %%
model3.fit(X1, Y1)
# Out:
# CategoricalNB()

# %%
model3.score(x2, y2)
# Out:
# 0.9408284023668639

# %%
y_pred=model3.predict(x2)

# %%
from sklearn.metrics import classification_report

print(classification_report(y2, y_pred, digits=4))
# Out:
#                                                                                  precision    recall  f1-score   support
#
# Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.     0.4615    1.0000    0.6316         6
#    Eustress (Positive Stress) - Stress that motivates and enhances performance.     0.9803    0.9551    0.9675       156
#                        No Stress - Currently experiencing minimal to no stress.     1.0000    0.5714    0.7273         7
#
#                                                                        accuracy                         0.9408       169
#                                                                       macro avg     0.8139    0.8422    0.7755       169
#                                                                    weighted avg     0.9627    0.9408    0.9457       169

# %%
from sklearn.ensemble import RandomForestClassifier

model4 = RandomForestClassifier(
    n_estimators=300,      
    max_depth=10,          
    min_samples_split=2,
    min_samples_leaf=1,
    class_weight="balanced"  
)
model4.fit(X1, Y1)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=300)

# %%
model4.score(x2,y2)
# Out:
# 0.9644970414201184

# %%
y_pred = model4.predict(x2)

# %%
precision, recall, f1, _ = precision_recall_fscore_support(y2, y_pred, average='weighted')

precision, recall, f1
# Out:
# (0.9658119658119657, 0.9644970414201184, 0.958914815228313)

# %%
y_pred = model3.predict(x2)

print(classification_report(y2, y_pred))
# Out:
#                                                                                  precision    recall  f1-score   support
#
# Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.       0.46      1.00      0.63         6
#    Eustress (Positive Stress) - Stress that motivates and enhances performance.       0.98      0.96      0.97       156
#                        No Stress - Currently experiencing minimal to no stress.       1.00      0.57      0.73         7
#
#                                                                        accuracy                           0.94       169
#                                                                       macro avg       0.81      0.84      0.78       169
#                                                                    weighted avg       0.96      0.94      0.95       169

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(model4, X1, Y1, cv=cv, scoring="f1_macro")
print("F1 Macro CV Scores:", scores)
print("Mean F1 Macro:", scores.mean())
# Out:
# F1 Macro CV Scores: [1.         0.98638218 0.98636047 0.99454667 0.9918366 ]
# Mean F1 Macro: 0.9918251821697155

# %%
import pickle
with open('stress_model.pkl','wb') as f:
    pickle.dump(model4,f)

# %%
from sklearn.metrics import confusion_matrix

cn= confusion_matrix(y2, y_pred)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

y_pred = model4.predict(x2)
cn = confusion_matrix(y2, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cn, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Random Forest')
plt.show()
plt.savefig("confusion_matrix.png")

# %%
plt.figure(figsize=(6,4))
sns.heatmap(cn, annot=True, fmt='d', cmap='Blues', xticklabels=['Distress', 'Eustress','No stress'], yticklabels=[ 'Distress','Eustress', 'No stress'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix - Random Forest")
plt.tight_layout()
plt.savefig("confusion_matrix_rf.png", dpi=300)
